# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set = pd.read_csv('winequality-red.csv')
data_set.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data_set.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
extra=data_set[data_set.duplicated()]
extra.shape
# Out:
# (240, 12)

# %%
y=data_set.quality
X=data_set.drop('quality', axis=1)
print(y.shape, X.shape)
# Out:
# (1599,) (1599, 11)

# %%
sns.set()
data_set.hist(figsize=(10,10), color='green')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
colormap=plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Korelasi antar variabel', y=1.05, size=15)
sns.heatmap(data_set.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, linecolor='white', annot=True)

# %%
y1=(y>5).astype(int)
y1.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: quality, dtype: int32

# %%
ax=y1.plot.hist(color='grey')
ax.set_title('distribusi kualitas aggur', fontsize=14)
ax.set_xlabel('nilai target')
# Out:
# Text(0.5, 0, 'nilai target')

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.metrics import confusion_matrix

# %%
seed=8
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size=0.2, random_state=seed)
